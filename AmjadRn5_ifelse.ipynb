# %% [markdown]
# 1. Write a Python program that takes an integer input and checks whether the number is even or odd.

# %%
number = int(input('Enter an integer number: '))
if number % 2 == 0:
    print ("The number is even")
else :
    print ("The number is odd")
# Out:
# Enter an integer number:  75
# The number is odd

# %% [markdown]
# 2. Write a Python program to input a student's marks and print "Pass" if the marks are 40 or above; otherwise,
# print "Fail."

# %%
marks = float(input ("Enter student's marks: "))
if marks >= 40:
    print ('Pass')
else:
    print ('Fail')
# Out:
# Enter student's marks:  65
# Pass

# %% [markdown]
# 3. Write a program that takes an integer as input and determines if it is positive, negative, or zero.

# %%
x = int(input ('Enter an integer: '))
if x == 0:
    print ('The integer is zero')
elif x > 0:
    print ('The integer is positive')
else:
    print ('The integer is negative')
# Out:
# Enter an integer:  0
# The integer is zero

# %% [markdown]
# 4. Write a Python program that inputs two numbers and prints which one is greater. If they are equal, print "Both
# are equal."

# %%
num1 = float(input('Enter first number: '))
num2 = float(input('Enter second number: '))
if num1 == num2:
    print ('Both are equal')
elif num1 < num2:
    print ('Second number is greater than first number')
else:
    print ('First number is greater than second number')
# Out:
# Enter first number:  6
# Enter second number:  3
# First number is greater than second number

# %% [markdown]
# 5. Write a program that takes a year as input and determines if it is a leap year. A year is a leap year if it is divisible
# by 4 but not divisible by 100, except if it is also divisible by 400.

# %%
year = int (input('Enter the year: '))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
     print ('This is a leap year')
else:
    print ('This is not a leap year')
# Out:
# Enter the year:  2003
# This is not a leap year

# %% [markdown]
# 6. Write a Python program that takes marks as input and prints the grade using the following conditions:\
#  90 and above: "A"\
#  80 to 89: "B"\
#  70 to 79: "C"\
#  60 to 69: "D"\
#  Below 60: "F"

# %%
marks = float (input ( 'Enter marks' ))
if marks >= 90 :
    print ('Grade A')
elif marks >= 80:
    print ('Grade B')
elif marks >= 70:
    print ('Grade C')
elif marks >= 60:
    print ('Grade D')
else:
    print ('Grade F')
# Out:
# Enter marks 40
# Grade F

# %% [markdown]
# 7. Write a program that takes three side lengths of a triangle as input and checks if they form a valid triangle. A
# triangle is valid if the sum of any two sides is greater than the third side.

# %%
side1 = float(input('Enter length of side 1'))
side2 = float(input('Enter length of side 2'))
side3 = float(input('Enter length of side 3'))
if ( side1 + side2 > side3) and ( side1 + side3 > side2) and ( side3 + side2 > side1):
    print ('Valid form triangle')
else:
    print ('Not Valid form triangle')
# Out:
# Enter length of side 1 3
# Enter length of side 2 3
# Enter length of side 3 7
# Not Valid form triangle

# %% [markdown]
# 8. Write a Python program that asks the user for their age and nationality. Print "Eligible to Vote" if the age is 18 or
# above and nationality is "Pakistani." Otherwise, print "Not Eligible to Vote."

# %%
age = float (input('Enter your age'))
nation = str (input('Enter your Nationality'))
if (age >= 18) and (nation == 'Pakistani'):
    print ('You are eligible to vote')
else:
    print ('You are not eligible to vote')
# Out:
# Enter your age 20
# Enter your Nationality Pakistani
# You are eligible to vote

# %% [markdown]
# 9. Write a Python program that takes an integer as input and classifies it:\
# o If divisible by 2 and 3, print "Divisible by both 2 and 3."\
# o If divisible by only 2, print "Divisible by 2."\
# o If divisible by only 3, print "Divisible by 3."\
# o Otherwise, print "Not divisible by 2 or 3."

# %%
y = int(input('Enter a number'))
if (y % 2 == 0) and (y % 3 == 0):
    print ('Divisible by both 2 and 3')
elif y % 2 == 0:
    print ('Divisble by 2')
elif y % 3 == 0:
    print ('Divisble by 3')
else:
    print ('Not divisible by 2 and 3')
# Out:
# Enter a number 1
# Not divisible by 2 and 3

# %% [markdown]
# 10. Write a Python program that takes three numbers as input and prints the largest number using nested if-else
# statements.

# %%
num1 = float(input('Enter number 1'))
num2 = float(input('Enter number 2'))
num3 = float(input('Enter number 3'))
if num1 > num2:
    if num1 > num3:
        largest = num1
    else:
        largest = num3
else:
    if num2 > num3:
        largest = num2
    else:
        largest = num3
    print ('The largest number is ', largest)
# Out:
# Enter number 1 6
# Enter number 2 3
# Enter number 3 8
