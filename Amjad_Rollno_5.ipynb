# %% [markdown]
# ### Assignment-02
# - Change the notebook name with your name and Roll Number.
# - Try this as your own, no chatgpt (it's for your learning)
# - after completing the assignment, submit this book on google class room.

# %% [markdown]
# Declare and print a variable with the name "name" containing your name.

# %%
name = 'Amjad';
print (name)
# Out:
# Amjad

# %% [markdown]
# Create two variables, x and y, and swap their values without using a third variable.

# %%
x = 25;
y = 15;
x , y = y , x
print ('x =', x)
print ('y =', y)
# Out:
# x = 15
# y = 25

# %% [markdown]
# Calculate the area of a rectangle with length and width stored in variables.

# %%
area = x*y
print ('Area of Rectangle', area)
# Out:
# Area of Rectangle 375

# %% [markdown]
# Create a variable with a long string (multi-line) and print its length.

# %%
longString = 'Create a variable \n with a long string \n and print its length'
length = len(longString)
print (longString)
print (length)
# Out:
# Create a variable
#  with a long string
#  and print its length
# 61

# %% [markdown]
# Create a variable to store your favorite number and print it.

# %%
m = 14
print ('My favorite number is ', m)
# Out:
# My favorite number is  14

# %% [markdown]
# Declare and assign values to multiple variables to represent the sides of a triangle. Calculate and print its perimeter.

# %%
x = 15
y = 20
z = 10
print ('the perimeters of traingle are', x + y + z)
# Out:
# the perimeters of traingle are 45

# %% [markdown]
# Store the price of an item in one variable and the quantity in another. Calculate and print the total cost.

# %%
price = 135
quantity = 354
totalCost = price * quantity
print ('The total cost of product is ', totalCost)
# Out:
# The total cost of product is  47790

# %% [markdown]
# Declare a constant variable for the value of pi (π) and use it to calculate the circumference of a circle with a given radius.

# %%
pi = 3.14
radius = 13
print ('The cicumference of circle is ', pi * 2 * radius)
# Out:
# The cicumference of circle is  81.64

# %% [markdown]
# Calculate the sum of two numbers, a and b.

# %%
a , b = 11 , 14
print (a+b)
# Out:
# 25

# %% [markdown]
# Calculate the product of two numbers, a and b.

# %%
print (a * b)
# Out:
# 154

# %% [markdown]
# Calculate the result of dividing a by b (with proper error handling for division by zero).

# %%
a = 10 
b = 2
print (a / b)
# Out:
# 5.0

# %% [markdown]
# Calculate the square of a number x.

# %%
print ('The square of x is ',x**2)
# Out:
# The square of x is  225

# %% [markdown]
# Calculate the remainder when a is divided by b.

# %%
print (a%b)
# Out:
# 0

# %% [markdown]
#  Calculate the result of dividing 17 by 3 and print the quotient and remainder.

# %%
print ('Quotient', 17 / 3)
print ('Remainder', 17 % 3)
# Out:
# Quotient 5.666666666666667
# Remainder 2

# %% [markdown]
# Calculate the area of a square with a given side length.

# %%
side = 7
area = side ** 2
print ('The area of a square with side length of', side , 'is ', area )
# Out:
# The area of a square with side length of 7 is  49

# %% [markdown]
# Calculate the average of five numbers.

# %%
avg = ((a + b+ x +y+ z)/2)
print (avg)
# Out:
# 28.5

# %% [markdown]
# Create a variable with a boolean value and print its opposite value.

# %%
good = 'true'
goodno = 'false'
print ('He is good:' , good)
print ('He is good:' , goodno)
# Out:
# He is good: true
# He is good: false

# %% [markdown]
# Store your birth year in a variable and calculate your age.

# %%
dob = 1999
now = 2024
print ('My is age is ', now - dob)
# Out:
# My is age is  25

# %% [markdown]
# Create a variable with an integer and convert it to a float.

# %%
t = 5
t = t + .43
print (t)
# Out:
# 5.43

# %% [markdown]
# Create a variable with a float and convert it to an integer.

# %%
t = int(t)
print (t)
# Out:
# 5

# %% [markdown]
# Create a variable with a string that represents an integer and convert it to an integer.

# %%
number = '25'
number = int(number)
print (number)
# Out:
# 25

# %% [markdown]
# Create a variable with a string that represents a float and convert it to a float.

# %%
floats = '25.22'
floats = float(floats)
print (floats)
# Out:
# 25.22

# %% [markdown]
# Create a variable with a number and convert it to a string.

# %%
strng = 86
string = str(strng)
print (strng)
print (string)
# Out:
# 86
# 86

# %% [markdown]
# Calculate the absolute value of a number.

# %%
c = -8
print ('the absolute value of -8 is ', abs (c))
# Out:
# the absolute value of -8 is  8

# %% [markdown]
# Calculate the square root of a number.

# %%
d = 10 
sq = d**1/2
print (sq)
# Out:
# 5.0

# %% [markdown]
# Calculate the value of a raised to the power of b.

# %%
result = a ** b
print ('Raised to the power b is ', result)
# Out:
# Raised to the power b is  100

# %% [markdown]
# Round a float to the nearest integer.

# %%
e = 10.86
f = round(e)
print (f)
# Out:
# 11

# %% [markdown]
# Combine multiple conditions using logical operators and print the result.

# %%
g = ((a + b - c)*(d *e/ f))
print (g)
# Out:
# 197.45454545454547

# %% [markdown]
# Generate a random number between 1 and 100.**(challenging)**

# %%
import random
h = [random.randint(1,100)]
print (h)
# Out:
# [94]
